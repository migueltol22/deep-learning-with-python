# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/migueltol22/deep-learning-with-python/blob/master/text_generation.ipynb)

# %%
# reweighting a probability distribution to a different temperature
import numpy as np

def reweight_distribution(original_distribution, temperature=0.5):
  distribution = np.log(original_distribution) / temperature
  distribution = np.exp(distribution)
  return distribution / np.sum(distribution)

# %%
import keras

# nietzche data
path = keras.utils.get_file(
  'nietszche.txt',
  origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length 600893

# %%
# vectorize sequences of characters

maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
  sentences.append(text[i: i + maxlen])
  next_chars.append(text[i + maxlen])
  
print('Number of sequences', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
  for t, char in enumerate(sentence):
    x[i, t, char_indices[char]] = 1
  y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences 200278
# Unique characters 57

# %%
# lstm model for next char prediction

from keras.layers import Dense, LSTM
from keras.models import Sequential
from keras.optimizers import RMSprop

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
  print('epoch', epoch)
  model.fit(x, y, batch_size=128, epochs=1)
  start_index = random.randint(0, len(text) - maxlen - 1)
  generated_text = text[start_index: start_index + maxlen]
  print('--- Generating with seed: "' + generated_text + '"' )
  
  for temperature in [0.2, 0.5, 1.0, 1.2]:
    print('----- temperature:', temperature)
    sys.stdout.write(generated_text)
    for i in range(400):
      sampled = np.zeros((1, maxlen, len(chars)))
      for t, char in enumerate(generated_text):
        sampled[0, t, char_indices[char]] = 1
        
      preds = model.predict(sampled, verbose=0)[0]
      next_index = sample(preds, temperature)
      next_char = chars[next_index]
      
      generated_text += next_char
      generated_text = generated_text[1:]
      
      sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 208s 1ms/step - loss: 1.5809
# --- Generating with seed: "f thought blended with it and all that remains is
# _strength_"
# ----- temperature: 0.2
# f thought blended with it and all that remains is
# _strength_ as a sure and the sense of the constance and the sense of the still the states of the sense of the sense of the still the still the constance of the sense of the supposer of the althing the good of the consequent of the constrance of the soul as the still as it is a soul in the constance of the hast to the constance of the consequent of the constance of the still as the consequent and the constan----- temperature: 0.5
# the constance of the still as the consequent and the constance in the perhaps a culture to the sense upon the consequence and sentiment that the not also the standers the significated and the destrise for the constrance of the fics in instance as only senses and fact with the self to much as sure moral guishter of the charage and in the sune such a
# good
# of the constrangering to the still the entimently and constance "from the contemption of the consequent ----- temperature: 1.0
# ently and constance "from the contemption of the consequent with the "eucourolow the indeptive at constlatover that ityraate it of this eriluble, of vorably grobling althece who has its one's here thou; enjicably arictliched, deep and responsible has ase,
# indeeffarration as only proges of , not alway thing to had a gooding a of perise as
# has has was "to d"teppreness may cimption aushition also created,
# other and inspining menss; at the smabon herrir,
# saint----- temperature: 1.2
# ated,
# other and inspining menss; at the smabon herrir,
# saint! and lapies not to; will the demomores the farm thsim ceet to everything,self--encourages as it old had rail, origind three of comrorixed to either and less hists his
# leady, a on
# impresency, al welcerss
# on
# 4quirely mawes; any bed also! their kind implay the, sley it in the objectualsful it epspriariture, is treserful it what has amose in, taitvated himselle--the girrsus of
# in mur hable cirle accoepoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 208s 1ms/step - loss: 1.5160
# --- Generating with seed: "ns, has reared all these
# "phenomena" and injected its own er"
# ----- temperature: 0.2
# ns, has reared all these
# "phenomena" and injected its own error and the artistic and the worst and distrust and such a man the disting the morality of the desires and the desires the disting the disting and such a surportion of the distingly and the states and the spirit of the sacrifice of the disting the strength of the supposing the devil to the disting the strength of the spirit the entimely of the stronger and something and profaction and the disclums----- temperature: 0.5
# f the stronger and something and profaction and the disclumstances of the inclunction. the other is all a delight of its arthsite and risely and such a good and lives and diseuth of the disting the way and the intellicated in the heart in all the does accompany inferious against the dutions of the self-signity and mitural because the science and stronger that we part of the most entimement in the only sympathest and inferious and its one of mankind have in----- temperature: 1.0
# only sympathest and inferious and its one of mankind have in may,
# than should tedicted of germany, and dingelful, pertadner from and the envises, it
# intacage, theredity as said of the wnoved,
# thisavolutions, this sight of came mevely larual propition, con
# calures affective fact to deilwidely blill to then celfor to dar,
# givinm which the feelingristmen with the deeped tastes; a look of the
# perierogmwhinally one riess ay syorly
# before himgers with all still
# ----- temperature: 1.2
# mwhinally one riess ay syorly
# before himgers with all still
# ander.netty, belief,
# a
# ccpetion,
# why
# cosies mast,, a geekivan othistive anysioking lidged impulsion, and inigencisle; even when only and to shopeety aspenth trakency
# and untimed faiurting
# where
# navoutive of obesten
# spy
# falw him"" in. inty away alto with" orpaid whavous this prexisolle baduheo--in eurationiwe
# supervision--wht, .n such revineved further
# reason tivism; and it. very
# begon, inably--i bepoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 209s 1ms/step - loss: 1.4774
# --- Generating with seed: "ring
# generally, in their almost feminine incapacity for witn"
# ----- temperature: 0.2
# ring
# generally, in their almost feminine incapacity for witnor and the farther of the comprehint in the strucged to the world and such all the strucger to be the comparent of the strucged the strucger and the strucger of the strucged to the strucged the most has a something and the belief and the strucger of the concerning the strucger of the strucged to the strength of the comprehint of the feeling and the compart of the strucger of the strucger of the st----- temperature: 0.5
# ng and the compart of the strucger of the strucger of the strucger of the wort of the same and been the into any sacrifice the reverence, and been the become that and belief of such an endure for the comes of the comparety of the operatic and propriated to count of the fact and as to be delight of the comes understand to which has a something means of such a some of a more been the democrting compart of the strucgh of we man force of the comprehendions and----- temperature: 1.0
# art of the strucgh of we man force of the comprehendions and desariare and "rusement the maltrrative, and divined. and that he goor higher with the cruald greekebs: bad wrical the sacrifice within this has, owh much inberively now fover christian deous ex us--a that all roind of an a serruss you is only mettopecue nom instimmtens of will has to it is the
# esthafting be the maifact to any knowncy to
# mistling in healthing meterasting, opive foin a finality in----- temperature: 1.2
#
# mistling in healthing meterasting, opive foin a finality in thus a baritofulchred it uscount without juct petoaks
# ?bvek yout fituuth, to sut odiolt as the most love learnes one's doliste. system living no lumile muchoma, mate late for tnet; witnon of proportnady
# aging, same valuanction cruat
# precisely which had onings be socly any question -out are, lith
# have eits sa sufferctom, and anseal a memostehte, was
# althess of signife, variection
# 1!
#
#    liw man isepoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 206s 1ms/step - loss: 1.4523
# --- Generating with seed: "of mankind by logical discipline
# and training of the intelle"
# ----- temperature: 0.2
# of mankind by logical discipline
# and training of the intellectual and in the sense of the superition of the suffer to the comes and the suffer the stand of the will to the sense of the state of the comes the superitical more and in the stand of the sunger and almost and the ways to the sunse the sure and come and the comes a man who be and the sunders and the strength of the sunger the superitical and the way and always the sun. the morality of the comes a----- temperature: 0.5
#  and the way and always the sun. the morality of the comes and individual in the truth tratic one such an and the man regrad as bothoughts the will to one who many higher such an interprets and its one comes and it was the superyt for it would the same to the sense the comes and intertucce and not to any says and instinct of the comes and the sense. he seems to an emocid outhurment and not to a disceneral and taushed and in the comes, the best and such a m----- temperature: 1.0
# sceneral and taushed and in the comes, the best and such a manquirrment, in the teeth and works, lithing--agay under sumpart
# of ancient iffection of nourity, each inove in high. -they can
# meve,
# and medictilial fact of
# to truth and not always without dangerity, and, at thet: and "man"" a langue, to the emucal desired coind mans taste, who not taim is the
# greedur. it will to covered that any give--althings classes imbight, and the purst al ankactsites closel----- temperature: 1.2
# lthings classes imbight, and the purst al ankactsites closely, especting fare, they recomelffary and to by has regard at . the inteplersiong endrumed solimal and cosesupory indeed, assablatian charm, su must
# tedrengue who mattriousknance generation sentimateveri8ts allops of it"fully
# presinged, opinion mere and at: letsom.--line femth
# of
# the almein mere as takes and if enhish yuczating logical sewky
# this
# diuplizing--noise" metrops an high hol
# abouttation, epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 204s 1ms/step - loss: 1.4310
# --- Generating with seed: "r
# and guide of humanity: and woe to him who would be such an"
# ----- temperature: 0.2
# r
# and guide of humanity: and woe to him who would be such any place of the present the end, and the conscious to the man the prisented the man and the for the senses the same the any one has a supposing the more and always and also the constrainess of the more and the man and been the the selfing and individual and the profound and the man and the man and the disposing the man and the world and also the prisented that the conscious to the prisenterism of t----- temperature: 0.5
# so the prisented that the conscious to the prisenterism of the person in the acts of the very let one himself of the person of the form of the consequently that one and the mankind,
# estame there may be delivered and in the cause and distingules, that there are desires of the belief and that seems the prisenties when the really which when the friends.
#
#
# 1n the superstions of the sentiment and man for the english and which the part and belief of the instinct----- temperature: 1.0
# or the english and which the part and belief of the instincts." to sought of diversational our severing, that human willisve sympathically same means. every perhaps they consequengly new indeptness sayspy unstill" which, bels--not
# be
# dissexving look--aid without here character, or that a advantage, or egooding. the morality
# of clinous
# slated and most subtlety. not call his own ataed
# trues,
# things came to very w, alparably and left betering. what had extrau----- temperature: 1.2
# came to very w, alparably and left betering. what had extraufines regard as
# as more thinks indindely ceash to 1quicnished most sorm's etogary differently arishory; less to be gooding thinglogor and remain of heves, itdindered hences,--lofful forterming--frilter wom
# an
# "should extencural lose,
# however, at thkneed whom
# courtefme against comprang; liched be spirle protrany agies cultuemness men in"s
# could of the willuhe and distandy charagemproriag to their
# depoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 209s 1ms/step - loss: 1.4174
# --- Generating with seed: "the same time, it
# would no longer be necessary, it would not"
# ----- temperature: 0.2
# the same time, it
# would no longer be necessary, it would not a stronger the stronged the person the greatest and present soul and in the sense of the senses and soul of the sense of the suffers of the sense of the present and in the sense of the present and sense of the philosophers and the sense of the present the strength of the sense of the strength of the farth and in the sense of the sensitions of the sense of the philosophers and the sense of the sen----- temperature: 0.5
# ns of the sense of the philosophers and the sense of the senses of the lave, and has the struggle the physiological belief it is as absolute and sacrifice, and it is a disconted the religious to the englished the developed, the present and persons of the will the suffering that the experience, which the interportain guise of the germans the greater the except and there are in the same on the german in a disposition that which one which the senses the whole----- temperature: 1.0
# n in a disposition that which one which the senses the whole they his own sounds as wier values. here always knowledgeness of the irrood man's man i speamisms; the learned, a 3-even of the
# ceased to "you blind it is sympathy when to the compulsities moduances of faith a proided, perhaps
# stupid englishpy for every
# called exist tyhist just the responsion
# and a wholly nature
# to they mean in all deer, to creveo
# and appryly, and hows, it
# they he ? endow i fomeu----- temperature: 1.2
#  to creveo
# and appryly, and hows, it
# they he ? endow i fomeumaccaiory, and we "why
# an immed precisely as admorality tormoritarly, whethers
# is somethinaxitical, just begins to the selfuyny my nature effovient, throse far small pers, soul pure "forderds the latter asmunted delicatite.
#
#
# 3oe
# sufficientsxhy has as werompaur, which
# man gever
# of
# inception in emotions the
# orasufulding," is rebounguly the milds
# says to phile or placia    showtrning spending that yepoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 212s 1ms/step - loss: 1.4029
# --- Generating with seed: "n do we write and paint,
# we mandarins with chinese brush, we"
# ----- temperature: 0.2
# n do we write and paint,
# we mandarins with chinese brush, we have not the strengthest and such and such and the self-security of the such all the senses of the believe the philosopher of the strengther of the subjection of the such and the end, and the self-suffered in the artists of the same the self-sense of the sense of the strengther with the such and are strong and provely strong of the man with the end, the self-such a some the strengthest and the se----- temperature: 0.5
# ith the end, the self-such a some the strengthest and the self-say, the only the most present species of such a such a such the oneself almost the strengther of many pressimes itself a possible: the strengther of a hard and such all in the self-such sense--the most of the conscience of priving the spirit of being the world and that the same the destructing men is the conscience of spiritual senses have even indeed the scribe of himself with a not to fears ----- temperature: 1.0
#  have even indeed the scribe of himself with a not to fears of the gerples? from the
# stating, were for i happences would humanical "spirit of this in-shese are difficulty), in inflict
# that everything brousphiflering
# has his flownouls is the versonging andment. too our "oncrs.
# it has there
# is deed without did air at one
# is "uplike dangerous tally reveriss. logicaling
# were opinions--he was routh of which
# our
# whol them only its burken madigable, and judgment
# ----- temperature: 1.2
# which
# our
# whol them only its burken madigable, and judgment
# ideas and
# selxetigurd of it
# can be
# darbised: gurfully gypy ?.
#
#
# 1a
#
#  indegbles which is believe made of all beinh; to discreptionita. errorlies.
#
# 123r amolgur! one seening thereby plenay--theaw, to bsing make
# in attapting in this judibed not konce.
#
# aoes havo of causewer virtuel of une; rends of herrank of powerful of decolt then far once domristic,"s in the
# todanies scriban falsified unawas sociaepoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 209s 1ms/step - loss: 1.3937
# --- Generating with seed: "er a smile and two notes of
# interrogation in a philosopher n"
# ----- temperature: 0.2
# er a smile and two notes of
# interrogation in a philosopher now the senses of the senses and actually senses and the considerable and superficial and the sense of the senses of the conscience of the states and presence of the conscience of the fearful and more and more and the conditions of the sense of the music, and and the senses the morality of the conscience of the conscience of the senses the strong, and the same the senses to the senses the senses an----- temperature: 0.5
#  strong, and the same the senses to the senses the senses and discovered the same the freedom of the conceal and threative and condution of wish that anyred the conditional hister, and though even the but one and and more all domain, and submanglent of which the senses of souls, that is its its any religious class and detasions of the more of the feeling of the world to himself of the opposing consequently sort of his concerning to the contrumted to the ag----- temperature: 1.0
# sequently sort of his concerning to the contrumted to the age is its botho free in the entity to
# unpersonal and does
# the
# proofic noges first, that of a copmental and advaticlening some psycholly, and the marksed for the inclases, at namial peoplementa, which at the sentimation that now, have ideas in order to thereby to says to have to
# even if tengul or whicha music, hands under po fit of past would be sole has us opiniently, differently more enchild from ----- temperature: 1.2
# ld be sole has us opiniently, differently more enchild from laystandeine his sort of ad"urest were to women fraysion. no its just be good in the concemptriling its easily to suffering, species are metanient
# the maly cen, the turranm", unude of maintalund of our evoluntiums
# from the one cate that i medewines for most kors, withoul any priloke
# tible or instinction? if only all--there
# when
# the way, naturally annietth about of
# woment is sursmntration of promorepoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 210s 1ms/step - loss: 1.3853
# --- Generating with seed: "n of this
# "from" and "towards" itself, and then besides, an "
# ----- temperature: 0.2
# n of this
# "from" and "towards" itself, and then besides, an allow the self-condition of the self-consideration of the strength and the strength and the world of the sense of the self-conscience of the world in the same the self-consideration of the self-considerate the soul and the self-conscious and the self-and the self-consideration of the sense of the strength of the sense of the significance of the self-consideration of the sense of the self-second to----- temperature: 0.5
# of the self-consideration of the sense of the self-second to the german present be considerate an allow of historical and provers an all the laws an in the make moral enemy preval man and good for the self-be significas and arts and
# degred necessity, and from an asculds of power and the for the become the present without now the worm, and be more man of the gent with the self-sear and distrust and really, the same to the faithed the present of the consider----- temperature: 1.0
#  really, the same to the faithed the present of the considerations of all fiet, with ove-didingunion. too are distrusiness of the compared to with the valuation of the gup our tern man
# all the forfifato, have so
# efferts of a humsigite of done beenoutful, sat, without agagne an accutuous--their gamp, theeth something duth decempt in
# preservate madideted that to pertatiges in the depires, however, be social strench of
# abtline prehenso
# bivan of the savad to t----- temperature: 1.2
# e social strench of
# abtline prehenso
# bivan of the savad to the stepidene, which he bais ass teeks
# and rabilal
# seclation what worth farutatice procinend, f
